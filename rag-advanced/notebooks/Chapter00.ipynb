# %% [markdown]
# <a href="https://colab.research.google.com/github/jerometr/WandbClass/blob/main/rag-advanced/notebooks/Chapter00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Chapter 0: Setup
#
# <a target="_blank" href="https://colab.research.google.com/github/wandb/edu/blob/main/rag-advanced/notebooks/Chapter00.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# <!--- @wandbcode{rag-course-00} -->
#
# Let's install the required packages and check our setup for this course.
#
# ### 🎉 Free Cohere API key
#
# Before you run this colab notebook, head over to this [link to redeem a free Cohere API key](https://docs.google.com/forms/d/e/1FAIpQLSc9x4nV8_nSQvJnaINO1j9NIa2IUbAJqrKeSllNNCCbMFmCxw/viewform?usp=sf_link).
#
# Alternatively if you have a Cohere API key feel free to proceed. :)

# %%
# !pip install -qq weave cohere
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 788.5/788.5 kB 15.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.0/319.0 kB 22.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 73.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 81.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 17.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 84.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 43.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 kB 8.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.

# %% [markdown]
# ## 1. Setup Weave
#
#
# The code cell below will prompt you to put in a W&B API key. You can get your API key by heading over to https://wandb.ai/authorize.

# %%
# import weave
import weave

# initialize weave client
weave_client = weave.init("rag-course")
# Out:
# weave: Please login to Weights & Biases (https://wandb.ai) to continue...
# wandb: WARNING The anonymous parameter to wandb.login() has no effect and will be removed in future versions.
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Find your API key here: https://wandb.ai/authorize?ref=weave
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: jerome-triomphe (jerome-triomphe-personal) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# weave: Logged in as Weights & Biases user: jerome-triomphe.
# weave: View Weave data at https://wandb.ai/jerome-triomphe-personal/rag-course/weave

# %% [markdown]
# ## 2. Setup Cohere
#
# The code cell below will prompt you to put in a Cohere API key.

# %%
import getpass

import cohere

cohere_client = cohere.ClientV2(
    api_key=getpass.getpass("Please enter your COHERE_API_KEY")
)
# Out:
# Please enter your COHERE_API_KEY··········

# %% [markdown]
# ## A simple-turn chat with Cohere's command-r-plus

# %%
response = cohere_client.chat(
    messages=[
        {"role": "user", "content": "What is retrieval augmented generation (RAG)?"}
    ],
    model="command-r-plus",
    temperature=0.1,
    max_tokens=2000,
)
# Out:
# weave: 🍩 https://wandb.ai/jerome-triomphe-personal/rag-course/r/call/019b7b79-fcc0-7ac7-8ba2-c08ef1606ea9
# ---------------------------------------------------------------------------
# TooManyRequestsError                      Traceback (most recent call last)
# /tmp/ipython-input-2804888157.py in <cell line: 0>()
# ----> 1 response = cohere_client.chat(
#       2     messages=[
#       3         {"role": "user", "content": "What is retrieval augmented generation (RAG)?"}
#       4     ],
#       5     model="command-r-plus",
#
# /usr/local/lib/python3.12/dist-packages/cohere/client.py in _wrapped(*args, **kwargs)
#     101                 "To suppress this warning, set `log_warning_experimental_features=False` when initializing the client."
#     102             )
# --> 103         return func(*args, **kwargs)
#     104
#     105     async def _async_wrapped(*args, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/cohere/client.py in _wrapped(*args, **kwargs)
#      33     def _wrapped(*args: typing.Any, **kwargs: typing.Any) -> typing.Any:
#      34         check_fn(*args, **kwargs)
# ---> 35         return method(*args, **kwargs)
#      36
#      37     async def _async_wrapped(*args: typing.Any, **kwargs: typing.Any) -> typing.Any:
#
# /usr/local/lib/python3.12/dist-packages/weave/trace/op.py in wrapper(*args, **kwargs)
#    1219                 @wraps(func)
#    1220                 def wrapper(*args: P.args, **kwargs: P.kwargs) -> R:
# -> 1221                     res, _ = _call_sync_func(
#    1222                         cast(Op[P, R], wrapper), *args, __should_raise=True, **kwargs
#    1223                     )
#
# /usr/local/lib/python3.12/dist-packages/weave/trace/op.py in _call_sync_func(op, __weave, __should_raise, __require_explicit_finish, *args, **kwargs)
#     504
#     505     try:
# --> 506         res = func(*args, **kwargs)
#     507     except Exception as e:
#     508         finish(exception=e)
#
# /usr/local/lib/python3.12/dist-packages/weave/integrations/cohere/cohere_sdk.py in _wrapper(*args, **kwargs)
#     126             @wraps(fn)
#     127             def _wrapper(*args: Any, **kwargs: Any) -> Any:
# --> 128                 response = fn(*args, **kwargs)
#     129
#     130                 try:
#
# /usr/local/lib/python3.12/dist-packages/cohere/v2/client.py in chat(self, model, messages, tools, strict_tools, documents, citation_options, response_format, safety_mode, max_tokens, stop_sequences, temperature, seed, frequency_penalty, presence_penalty, k, p, logprobs, tool_choice, thinking, priority, request_options)
#     358         )
#     359         """
# --> 360         _response = self._raw_client.chat(
#     361             model=model,
#     362             messages=messages,
#
# /usr/local/lib/python3.12/dist-packages/cohere/v2/raw_client.py in chat(self, model, messages, tools, strict_tools, documents, citation_options, response_format, safety_mode, max_tokens, stop_sequences, temperature, seed, frequency_penalty, presence_penalty, k, p, logprobs, tool_choice, thinking, priority, request_options)
#     633                 )
#     634             if _response.status_code == 429:
# --> 635                 raise TooManyRequestsError(
#     636                     headers=dict(_response.headers),
#     637                     body=typing.cast(
#
# TooManyRequestsError: headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': '764d0e769fd45675ce6826ecc338dbea', 'date': 'Thu, 01 Jan 2026 21:32:30 GMT', 'x-envoy-upstream-service-time': '15', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': '033704a8-75e9-4bff-b83c-6ad2e4c309d4', 'message': 'Please wait and try again later'}

# %% [markdown]
# Let's head over to the weave URL to check out the generated response.
